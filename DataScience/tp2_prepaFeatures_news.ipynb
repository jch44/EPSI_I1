# %% [markdown]
#  ============================================================
#
#  TP FEATURE ENGINEERING – ONLINE NEWS POPULARITY
#
#  Objectif : Préparer un dataset exploitable pour ML
#
#  ============================================================

# %% [markdown]
#  ### 1. Import des librairies

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import mutual_info_classif
# Affichage de l'ensemble des colonnes et lignes
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
#  ### 2. Chargement des données
#
#  Exercice : Charger le fichier CSV, afficher les premières lignes et identifier la variable cible potentielle

# %% [markdown]
#  ### 3. Création de la variable cible `viral`
#
#  Exercice : Créer une variable binaire `viral` qui vaut 1 si le nombre de partages est supérieur au double de la médiane, 0 sinon

# %% [markdown]
#  ### 4. Sélection initiale des variables pour le TP
#
#  - Supprimer les colonnes non prédictives (url, shares)
#
#  - Garder les variables numériques et binaires

# %% [markdown]
#  ### 5. Traitement données manquantes

# %% [markdown]
# #### 5.1 Identifier les colonnes incomplètes

# %% [markdown]
# #### 5.2 Définir et justifier une stratégie pour compléter les données de chaque colonne
# écrire ici...

# %% [markdown]
# #### 5.3 Mettre en oeuvre la complétion des données (une cellule par colonne traitée)

# %% [markdown]
#  ### 6. Feature Engineering
#
#  Exercice : Créer de nouvelles variables métier
#
#  - article long / court (Plus de 1000 mots)
#
#  - ratio images / mots
#
#  - multimédia (images ou vidéos)
#
#  - contenu émotionnel fort

# %% [markdown]
#  ### 7. Mutual Information

# %% [markdown]
#  #### 7.1 Calcul de la Mutual Information
#
#  Exercice : Calculer la MI entre chaque feature et la variable cible

# %% [markdown]
#  #### 7.2. Sélection des features
#
#  Exercice : Conserver uniquement les features ayant une Information Mutuelle > 0.01

# %% [markdown]
#  ### 8. Mise en forme finale

# %% [markdown]
# #### 8.1 Standardisation
# Exercice : Standardiser les variables numériques

# %% [markdown]
#  #### 8.2. Vérification
#  Vérifier que les données sont prêtes pour un traitement de Machine Learning

# %% [markdown]
#  #### 8.3 Création de données d'apprentissage et de test
#
#  Exercice : Préparer les datasets d'entraînement et de test (proportion 80 / 20)

# %% [markdown]
#  ### 9. Sauvegarde du dataset préparé
#
#  Exercice : Sauvegarder les datasets
